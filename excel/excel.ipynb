# %% [markdown]
# #### Why learn to work with Excel with Python? Excel is one of the most popular and widely-used data tools;
# #### It’s hard to find an organization that doesn’t work with it in some way.
# #### From analysts, to sales VPs, to CEOs, various professionals use Excel for both quick stats and serious data crunching.

# %% [markdown]
# #### With Excel being so pervasive, data professionals must be familiar with it. A way to work with Excel using code is critical.
# #### Thankfully, there’s a great tool already out there for using Excel with Python called pandas.

# %% [markdown]
# #### Pandas has excellent methods for reading all kinds of data from Excel files. You can also export your results from pandas back to Excel, if that’s preferred by your intended audience. Pandas is great for other routine data analysis tasks, such as:
#
# ##### quick Exploratory Data Analysis (EDA)
# ##### drawing attractive plots
# ##### feeding data into machine learning tools like scikit-learn
# ##### building machine learning models on your data
# ##### taking cleaned and processed data to any number of data tools'''

# %% [markdown]
# ### System Prerequisites:-
# ##### We will use Python 3 and VS code to demonstrate the code in this tutorial.

# %% [markdown]
# #### Our Excel file has three sheets: ‘1900s,’ ‘2000s,’ and ‘2010s.’ Each sheet has data for movies from those years. We will use this data set to find the ratings distribution for the movies, visualize movies with highest ratings and net earnings and calculate statistical information about the movies. We will be analyzing and exploring this data using Python and pandas

# %%
import pandas as pd
excel_file = 'movies.xls'
movies = pd.read_excel(excel_file)

# %%
movies.head()
# Out:
#                                                Title  Year  \
# 0  Intolerance: Love's Struggle Throughout the Ages   1916
# 1                    Over the Hill to the Poorhouse   1920
# 2                                    The Big Parade   1925
# 3                                        Metropolis   1927
# 4                                     Pandora's Box   1929
#
#                 Genres Language  Country Content Rating  Duration  \
# 0    Drama|History|War      NaN      USA      Not Rated       123
# 1          Crime|Drama      NaN      USA            NaN       110
# 2    Drama|Romance|War      NaN      USA      Not Rated       151
# 3         Drama|Sci-Fi   German  Germany      Not Rated       145
# 4  Crime|Drama|Romance   German  Germany      Not Rated       110
#
#    Aspect Ratio     Budget  Gross Earnings  ... Facebook Likes - Actor 1  \
# 0          1.33   385907.0             NaN  ...                      436
# 1          1.33   100000.0       3000000.0  ...                        2
# 2          1.33   245000.0             NaN  ...                       81
# 3          1.33  6000000.0         26435.0  ...                      136
# 4          1.33        NaN          9950.0  ...                      426
#
#   Facebook Likes - Actor 2 Facebook Likes - Actor 3  \
# 0                       22                      9.0
# 1                        2                      0.0
# 2                       12                      6.0
# 3                       23                     18.0
# 4                       20                      3.0
#
#   Facebook Likes - cast Total  Facebook likes - Movie  Facenumber in posters  \
# 0                         481                     691                      1
# 1                           4                       0                      1
# 2                         108                     226                      0
# 3                         203                   12000                      1
# 4                         455                     926                      1
#
#    User Votes  Reviews by Users  Reviews by Crtiics  IMDB Score
# 0       10718                88                69.0         8.0
# 1           5                 1                 1.0         4.8
# 2        4849                45                48.0         8.3
# 3      111841               413               260.0         8.3
# 4        7431                84                71.0         8.0
#
# [5 rows x 25 columns]

# %%
'''Excel files quite often have multiple sheets and the ability to read a specific sheet or all of them is very important. To make this easy, the pandas read_excel method takes an argument called sheetname that tells pandas which sheet to read in the data from. For this, you can either use the sheet name or the sheet number. Sheet numbers start with zero. If the sheetname argument is not given, it defaults to zero and pandas will import the first sheet.
we are choosing the first column, ‘Title’, as index (index=0) by passing zero to the index_col argument.'''

# %%
movies_sheet1 = pd.read_excel(excel_file, sheet_name=0, index_col=0)
movies_sheet1.head()
# Out:
#                                                    Year               Genres  \
# Title
# Intolerance: Love's Struggle Throughout the Ages   1916    Drama|History|War
# Over the Hill to the Poorhouse                     1920          Crime|Drama
# The Big Parade                                     1925    Drama|Romance|War
# Metropolis                                         1927         Drama|Sci-Fi
# Pandora's Box                                      1929  Crime|Drama|Romance
#
#                                                   Language  Country  \
# Title
# Intolerance: Love's Struggle Throughout the Ages       NaN      USA
# Over the Hill to the Poorhouse                         NaN      USA
# The Big Parade                                         NaN      USA
# Metropolis                                          German  Germany
# Pandora's Box                                       German  Germany
#
#                                                   Content Rating  Duration  \
# Title
# Intolerance: Love's Struggle Throughout the Ages       Not Rated       123
# Over the Hill to the Poorhouse                               NaN       110
# The Big Parade                                         Not Rated       151
# Metropolis                                             Not Rated       145
# Pandora's Box                                          Not Rated       110
#
#                                                    Aspect Ratio     Budget  \
# Title
# Intolerance: Love's Struggle Throughout the Ages           1.33   385907.0
# Over the Hill to the Poorhouse                             1.33   100000.0
# The Big Parade                                             1.33   245000.0
# Metropolis                                                 1.33  6000000.0
# Pandora's Box                                              1.33        NaN
#
#                                                    Gross Earnings  \
# Title
# Intolerance: Love's Struggle Throughout the Ages              NaN
# Over the Hill to the Poorhouse                          3000000.0
# The Big Parade                                                NaN
# Metropolis                                                26435.0
# Pandora's Box                                              9950.0
#
#                                                               Director  ...  \
# Title                                                                   ...
# Intolerance: Love's Struggle Throughout the Ages         D.W. Griffith  ...
# Over the Hill to the Poorhouse                       Harry F. Millarde  ...
# The Big Parade                                              King Vidor  ...
# Metropolis                                                  Fritz Lang  ...
# Pandora's Box                                      Georg Wilhelm Pabst  ...
#
#                                                   Facebook Likes - Actor 1  \
# Title
# Intolerance: Love's Struggle Throughout the Ages                       436
# Over the Hill to the Poorhouse                                           2
# The Big Parade                                                          81
# Metropolis                                                             136
# Pandora's Box                                                          426
#
#                                                   Facebook Likes - Actor 2  \
# Title
# Intolerance: Love's Struggle Throughout the Ages                        22
# Over the Hill to the Poorhouse                                           2
# The Big Parade                                                          12
# Metropolis                                                              23
# Pandora's Box                                                           20
#
#                                                   Facebook Likes - Actor 3  \
# Title
# Intolerance: Love's Struggle Throughout the Ages                       9.0
# Over the Hill to the Poorhouse                                         0.0
# The Big Parade                                                         6.0
# Metropolis                                                            18.0
# Pandora's Box                                                          3.0
#
#                                                    Facebook Likes - cast Total  \
# Title
# Intolerance: Love's Struggle Throughout the Ages                           481
# Over the Hill to the Poorhouse                                               4
# The Big Parade                                                             108
# Metropolis                                                                 203
# Pandora's Box                                                              455
#
#                                                    Facebook likes - Movie  \
# Title
# Intolerance: Love's Struggle Throughout the Ages                      691
# Over the Hill to the Poorhouse                                          0
# The Big Parade                                                        226
# Metropolis                                                          12000
# Pandora's Box                                                         926
#
#                                                    Facenumber in posters  \
# Title
# Intolerance: Love's Struggle Throughout the Ages                       1
# Over the Hill to the Poorhouse                                         1
# The Big Parade                                                         0
# Metropolis                                                             1
# Pandora's Box                                                          1
#
#                                                    User Votes  \
# Title
# Intolerance: Love's Struggle Throughout the Ages        10718
# Over the Hill to the Poorhouse                              5
# The Big Parade                                           4849
# Metropolis                                             111841
# Pandora's Box                                            7431
#
#                                                    Reviews by Users  \
# Title
# Intolerance: Love's Struggle Throughout the Ages                 88
# Over the Hill to the Poorhouse                                    1
# The Big Parade                                                   45
# Metropolis                                                      413
# Pandora's Box                                                    84
#
#                                                    Reviews by Crtiics  \
# Title
# Intolerance: Love's Struggle Throughout the Ages                 69.0
# Over the Hill to the Poorhouse                                    1.0
# The Big Parade                                                   48.0
# Metropolis                                                      260.0
# Pandora's Box                                                    71.0
#
#                                                    IMDB Score
# Title
# Intolerance: Love's Struggle Throughout the Ages          8.0
# Over the Hill to the Poorhouse                            4.8
# The Big Parade                                            8.3
# Metropolis                                                8.3
# Pandora's Box                                             8.0
#
# [5 rows x 24 columns]

# %%
movies_sheet2 = pd.read_excel(excel_file, sheet_name=1, index_col=0)
movies_sheet2.head()
# Out:
#                         Year                   Genres Language Country  \
# Title
# 102 Dalmatians          2000  Adventure|Comedy|Family  English     USA
# 28 Days                 2000             Comedy|Drama  English     USA
# 3 Strikes               2000                   Comedy  English     USA
# Aberdeen                2000                    Drama  English      UK
# All the Pretty Horses   2000    Drama|Romance|Western  English     USA
#
#                        Content Rating  Duration  Aspect Ratio      Budget  \
# Title
# 102 Dalmatians                      G     100.0          1.85  85000000.0
# 28 Days                         PG-13     103.0          1.37  43000000.0
# 3 Strikes                           R      82.0          1.85   6000000.0
# Aberdeen                          NaN     106.0          1.85   6500000.0
# All the Pretty Horses           PG-13     220.0          2.35  57000000.0
#
#                         Gross Earnings            Director  ...  \
# Title                                                       ...
# 102 Dalmatians              66941559.0          Kevin Lima  ...
# 28 Days                     37035515.0        Betty Thomas  ...
# 3 Strikes                    9821335.0             DJ Pooh  ...
# Aberdeen                       64148.0  Hans Petter Moland  ...
# All the Pretty Horses       15527125.0  Billy Bob Thornton  ...
#
#                        Facebook Likes - Actor 1 Facebook Likes - Actor 2  \
# Title
# 102 Dalmatians                           2000.0                    795.0
# 28 Days                                 12000.0                  10000.0
# 3 Strikes                                 939.0                    706.0
# Aberdeen                                  844.0                      2.0
# All the Pretty Horses                   13000.0                    861.0
#
#                        Facebook Likes - Actor 3  Facebook Likes - cast Total  \
# Title
# 102 Dalmatians                            439.0                         4182
# 28 Days                                   664.0                        23864
# 3 Strikes                                 585.0                         3354
# Aberdeen                                    0.0                          846
# All the Pretty Horses                     820.0                        15006
#
#                         Facebook likes - Movie  Facenumber in posters  \
# Title
# 102 Dalmatians                             372                      1
# 28 Days                                      0                      1
# 3 Strikes                                  118                      1
# Aberdeen                                   260                      0
# All the Pretty Horses                      652                      2
#
#                         User Votes  Reviews by Users  Reviews by Crtiics  \
# Title
# 102 Dalmatians               26413              77.0                84.0
# 28 Days                      34597             194.0               116.0
# 3 Strikes                     1415              10.0                22.0
# Aberdeen                      2601              35.0                28.0
# All the Pretty Horses        11388             183.0                85.0
#
#                         IMDB Score
# Title
# 102 Dalmatians                 4.8
# 28 Days                        6.0
# 3 Strikes                      4.0
# Aberdeen                       7.3
# All the Pretty Horses          5.8
#
# [5 rows x 24 columns]

# %%
movies_sheet3 = pd.read_excel(excel_file, sheet_name=2, index_col=0)
movies_sheet3.head()
# Out:
#                                         Year  \
# Title
# 127 Hours                             2010.0
# 3 Backyards                           2010.0
# 3                                     2010.0
# 8: The Mormon Proposition             2010.0
# A Turtle's Tale: Sammy's Adventures   2010.0
#
#                                                                   Genres  \
# Title
# 127 Hours                             Adventure|Biography|Drama|Thriller
# 3 Backyards                                                        Drama
# 3                                                   Comedy|Drama|Romance
# 8: The Mormon Proposition                                    Documentary
# A Turtle's Tale: Sammy's Adventures           Adventure|Animation|Family
#
#                                      Language  Country Content Rating  \
# Title
# 127 Hours                             English      USA              R
# 3 Backyards                           English      USA              R
# 3                                      German  Germany        Unrated
# 8: The Mormon Proposition             English      USA              R
# A Turtle's Tale: Sammy's Adventures   English   France             PG
#
#                                       Duration  Aspect Ratio      Budget  \
# Title
# 127 Hours                                 94.0          1.85  18000000.0
# 3 Backyards                               88.0           NaN    300000.0
# 3                                        119.0          2.35         NaN
# 8: The Mormon Proposition                 80.0          1.78   2500000.0
# A Turtle's Tale: Sammy's Adventures       88.0          2.35         NaN
#
#                                       Gross Earnings         Director  ...  \
# Title                                                                  ...
# 127 Hours                                 18329466.0      Danny Boyle  ...
# 3 Backyards                                      NaN  Eric Mendelsohn  ...
# 3                                            59774.0       Tom Tykwer  ...
# 8: The Mormon Proposition                    99851.0       Reed Cowan  ...
# A Turtle's Tale: Sammy's Adventures              NaN      Ben Stassen  ...
#
#                                      Facebook Likes - Actor 1  \
# Title
# 127 Hours                                             11000.0
# 3 Backyards                                             795.0
# 3                                                        24.0
# 8: The Mormon Proposition                               191.0
# A Turtle's Tale: Sammy's Adventures                     783.0
#
#                                      Facebook Likes - Actor 2  \
# Title
# 127 Hours                                               642.0
# 3 Backyards                                             659.0
# 3                                                        20.0
# 8: The Mormon Proposition                                12.0
# A Turtle's Tale: Sammy's Adventures                     749.0
#
#                                      Facebook Likes - Actor 3  \
# Title
# 127 Hours                                               223.0
# 3 Backyards                                             301.0
# 3                                                         9.0
# 8: The Mormon Proposition                                 5.0
# A Turtle's Tale: Sammy's Adventures                     602.0
#
#                                       Facebook Likes - cast Total  \
# Title
# 127 Hours                                                   11984
# 3 Backyards                                                  1884
# 3                                                              69
# 8: The Mormon Proposition                                     210
# A Turtle's Tale: Sammy's Adventures                          3874
#
#                                       Facebook likes - Movie  \
# Title
# 127 Hours                                              63000
# 3 Backyards                                               92
# 3                                                       2000
# 8: The Mormon Proposition                                  0
# A Turtle's Tale: Sammy's Adventures                        0
#
#                                       Facenumber in posters  User Votes  \
# Title
# 127 Hours                                               0.0      279179
# 3 Backyards                                             0.0         554
# 3                                                       0.0        4212
# 8: The Mormon Proposition                               0.0        1138
# A Turtle's Tale: Sammy's Adventures                     2.0        5385
#
#                                       Reviews by Users  Reviews by Crtiics  \
# Title
# 127 Hours                                        440.0               450.0
# 3 Backyards                                       23.0                20.0
# 3                                                 18.0                76.0
# 8: The Mormon Proposition                         30.0                28.0
# A Turtle's Tale: Sammy's Adventures               22.0                56.0
#
#                                       IMDB Score
# Title
# 127 Hours                                    7.6
# 3 Backyards                                  5.2
# 3                                            6.8
# 8: The Mormon Proposition                    7.1
# A Turtle's Tale: Sammy's Adventures          6.1
#
# [5 rows x 24 columns]

# %% [markdown]
# #### Since all the three sheets have similar data but for different recordsmovies, we will create a single DataFrame from all the three DataFrames we created above. We will use the pandas concat method for this and pass in the names of the three DataFrames we just created and assign the results to a new DataFrame object, movies.

# %%
movies = pd.concat([movies_sheet1, movies_sheet2, movies_sheet3])

# %%
movies.shape
# Out:
# (5042, 24)

# %% [markdown]
# #### If you are reading an Excel file with a lot of sheets and are creating a lot of DataFrames, ExcelFile is more convenient and efficient in comparison to read_excel. With ExcelFile, you only need to pass the Excel file once, and then you can use it to get the DataFrames. When using read_excel, you pass the Excel file every time and hence the file is loaded again for every sheet. This can be a huge performance drag if the Excel file has many sheets with a large number of rows.

# %%
# xlsx = pd.ExcelFile(excel_file)
# movies_sheets = []
# for sheet in xlsx.sheet_names:
#    movies_sheets.append(xlsx.parse(sheet))
# movies = pd.concat(movies_sheets)

# %%
# Exploring the data
movies.tail()
# Out:
#                                       Year  \
# Title
# War & Peace                            NaN
# Wings                                  NaN
# Wolf Creek                             NaN
# Wuthering Heights                      NaN
# Yu-Gi-Oh! Duel Monsters                NaN
#
#                                                                          Genres  \
# Title
# War & Peace                                           Drama|History|Romance|War
# Wings                                                              Comedy|Drama
# Wolf Creek                                                Drama|Horror|Thriller
# Wuthering Heights                                                 Drama|Romance
# Yu-Gi-Oh! Duel Monsters               Action|Adventure|Animation|Family|Fantasy
#
#                                       Language    Country Content Rating  \
# Title
# War & Peace                            English         UK          TV-14
# Wings                                  English        USA            NaN
# Wolf Creek                             English  Australia            NaN
# Wuthering Heights                      English         UK            NaN
# Yu-Gi-Oh! Duel Monsters               Japanese      Japan            NaN
#
#                                       Duration  Aspect Ratio  Budget  \
# Title
# War & Peace                                NaN         16.00     NaN
# Wings                                     30.0          1.33     NaN
# Wolf Creek                                 NaN          2.00     NaN
# Wuthering Heights                        142.0           NaN     NaN
# Yu-Gi-Oh! Duel Monsters                   24.0           NaN     NaN
#
#                                       Gross Earnings Director  ...  \
# Title                                                          ...
# War & Peace                                      NaN      NaN  ...
# Wings                                            NaN      NaN  ...
# Wolf Creek                                       NaN      NaN  ...
# Wuthering Heights                                NaN      NaN  ...
# Yu-Gi-Oh! Duel Monsters                          NaN      NaN  ...
#
#                                      Facebook Likes - Actor 1  \
# Title
# War & Peace                                            1000.0
# Wings                                                   685.0
# Wolf Creek                                              511.0
# Wuthering Heights                                     27000.0
# Yu-Gi-Oh! Duel Monsters                                   0.0
#
#                                      Facebook Likes - Actor 2  \
# Title
# War & Peace                                             888.0
# Wings                                                   511.0
# Wolf Creek                                              457.0
# Wuthering Heights                                       698.0
# Yu-Gi-Oh! Duel Monsters                                   NaN
#
#                                      Facebook Likes - Actor 3  \
# Title
# War & Peace                                             502.0
# Wings                                                   424.0
# Wolf Creek                                              206.0
# Wuthering Heights                                       427.0
# Yu-Gi-Oh! Duel Monsters                                   NaN
#
#                                       Facebook Likes - cast Total  \
# Title
# War & Peace                                                  4528
# Wings                                                        1884
# Wolf Creek                                                   1617
# Wuthering Heights                                           29196
# Yu-Gi-Oh! Duel Monsters                                         0
#
#                                       Facebook likes - Movie  \
# Title
# War & Peace                                            11000
# Wings                                                   1000
# Wolf Creek                                               954
# Wuthering Heights                                          0
# Yu-Gi-Oh! Duel Monsters                                  124
#
#                                       Facenumber in posters  User Votes  \
# Title
# War & Peace                                             1.0        9277
# Wings                                                   5.0        7646
# Wolf Creek                                              0.0         726
# Wuthering Heights                                       2.0        6053
# Yu-Gi-Oh! Duel Monsters                                 0.0       12417
#
#                                       Reviews by Users  Reviews by Crtiics  \
# Title
# War & Peace                                       44.0                10.0
# Wings                                             56.0                19.0
# Wolf Creek                                         6.0                 2.0
# Wuthering Heights                                 33.0                 9.0
# Yu-Gi-Oh! Duel Monsters                           51.0                 6.0
#
#                                       IMDB Score
# Title
# War & Peace                                  8.2
# Wings                                        7.3
# Wolf Creek                                   7.1
# Wuthering Heights                            7.7
# Yu-Gi-Oh! Duel Monsters                      7.0
#
# [5 rows x 24 columns]

# %%
# let’s sort our movies DataFrame based on the Gross Earnings column.
sorted_by_gross = movies.sort_values(['Gross Earnings'], ascending=False)
sorted_by_gross["Gross Earnings"].head(10)
# Out:
# Title
# Avatar                                        760505847.0
# Titanic                                       658672302.0
# Jurassic World                                652177271.0
# The Avengers                                  623279547.0
# The Avengers                                  623279547.0
# The Dark Knight                               533316061.0
# Star Wars: Episode I - The Phantom Menace     474544677.0
# Star Wars: Episode IV - A New Hope            460935665.0
# Avengers: Age of Ultron                       458991599.0
# The Dark Knight Rises                         448130642.0
# Name: Gross Earnings, dtype: float64

# %% [markdown]
# #### We can also create a plot for the top 10 movies by Gross Earnings. Pandas makes it easy to visualize your data with plots and charts through matplotlib, a popular data visualization library. With a couple lines of code, you can start plotting. Moreover, matplotlib plots work well inside Jupyter Notebooks since you can displace the plots right under the code.

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
sorted_by_gross['Gross Earnings'].head(10).plot(kind="barh")
plt.show()

# %% [markdown]
# #### Let’s create a histogram of IMDB Scores to check the distribution of IMDB Scores across all movies. Histograms are a good way to visualize the distribution of a data set

# %%
movies['IMDB Score'].plot(kind="hist")
plt.show()

# %% [markdown]
# #### Getting statistical information about the data

# %%
movies.describe()
# Out:
#               Year     Duration  Aspect Ratio        Budget  Gross Earnings  \
# count  4935.000000  5028.000000   4714.000000  4.551000e+03    4.159000e+03
# mean   2002.470517   107.201074      2.220403  3.975262e+07    4.846841e+07
# std      12.474599    25.197441      1.385113  2.061149e+08    6.845299e+07
# min    1916.000000     7.000000      1.180000  2.180000e+02    1.620000e+02
# 25%    1999.000000    93.000000      1.850000  6.000000e+06    5.340988e+06
# 50%    2005.000000   103.000000      2.350000  2.000000e+07    2.551750e+07
# 75%    2011.000000   118.000000      2.350000  4.500000e+07    6.230944e+07
# max    2016.000000   511.000000     16.000000  1.221550e+10    7.605058e+08
#
#        Facebook Likes - Director  Facebook Likes - Actor 1  \
# count                4938.000000               5035.000000
# mean                  686.621709               6561.323932
# std                  2813.602405              15021.977635
# min                     0.000000                  0.000000
# 25%                     7.000000                614.500000
# 50%                    49.000000                988.000000
# 75%                   194.750000              11000.000000
# max                 23000.000000             640000.000000
#
#        Facebook Likes - Actor 2  Facebook Likes - Actor 3  \
# count               5029.000000               5020.000000
# mean                1652.080533                645.009761
# std                 4042.774685               1665.041728
# min                    0.000000                  0.000000
# 25%                  281.000000                133.000000
# 50%                  595.000000                371.500000
# 75%                  918.000000                636.000000
# max               137000.000000              23000.000000
#
#        Facebook Likes - cast Total  Facebook likes - Movie  \
# count                  5042.000000             5042.000000
# mean                   9700.959143             7527.457160
# std                   18165.101925            19322.070537
# min                       0.000000                0.000000
# 25%                    1411.250000                0.000000
# 50%                    3091.000000              166.000000
# 75%                   13758.750000             3000.000000
# max                  656730.000000           349000.000000
#
#        Facenumber in posters    User Votes  Reviews by Users  \
# count            5029.000000  5.042000e+03       5022.000000
# mean                1.371446  8.368475e+04        272.770808
# std                 2.013683  1.384940e+05        377.982886
# min                 0.000000  5.000000e+00          1.000000
# 25%                 0.000000  8.599250e+03         65.000000
# 50%                 1.000000  3.437100e+04        156.000000
# 75%                 2.000000  9.634700e+04        326.000000
# max                43.000000  1.689764e+06       5060.000000
#
#        Reviews by Crtiics   IMDB Score
# count         4993.000000  5042.000000
# mean           140.194272     6.442007
# std            121.601675     1.125189
# min              1.000000     1.600000
# 25%             50.000000     5.800000
# 50%            110.000000     6.600000
# 75%            195.000000     7.200000
# max            813.000000     9.500000

# %% [markdown]
# #### he describe method displays below information for each of the columns.
#
# ##### the count or number of values
# ##### mean
# ##### standard deviation
# ##### minimum, maximum
# ##### 25%, 50%, and 75% quantile

# %%
movies["Gross Earnings"].mean()
# Out:
# 48468407.52680933

# %% [markdown]
# #### One of the much-used features of Excel is to apply formulas to create new columns from existing column values. In our Excel file, we have Gross Earnings and Budget columns. We can get Net earnings by subtracting Budget from Gross earnings. We could then apply this formula in the Excel file to all the rows.

# %%
movies["Net Earnings"] = movies["Gross Earnings"] - movies["Budget"]

# %%
print(movies["Net Earnings"].head(50))
# Out:
# Title
# Intolerance: Love's Struggle Throughout the Ages             NaN
# Over the Hill to the Poorhouse                         2900000.0
# The Big Parade                                               NaN
# Metropolis                                            -5973565.0
# Pandora's Box                                                NaN
# The Broadway Melody                                    2429000.0
# Hell's Angels                                                NaN
# A Farewell to Arms                                           NaN
# 42nd Street                                            1861000.0
# She Done Him Wrong                                           NaN
# It Happened One Night                                        NaN
# Top Hat                                                2391000.0
# Modern Times                                          -1336755.0
# The Charge of the Light Brigade                              NaN
# Snow White and the Seven Dwarfs                      182925485.0
# The Prisoner of Zenda                                        NaN
# Alexander's Ragtime Band                                     NaN
# You Can't Take It with You                                   NaN
# Gone with the Wind                                   194678278.0
# Mr. Smith Goes to Washington                                 NaN
# The Wizard of Oz                                      19402612.0
# Boom Town                                                    NaN
# Fantasia                                              74120000.0
# Pinocchio                                             81700000.0
# Rebecca                                                      NaN
# The Blue Bird                                                NaN
# How Green Was My Valley                                      NaN
# Bambi                                                        NaN
# Casablanca                                                   NaN
# A Guy Named Joe                                              NaN
# Bathing Beauty                                               NaN
# Spellbound                                                   NaN
# State Fair                                                   NaN
# The Lost Weekend                                             NaN
# The Valley of Decision                                       NaN
# Duel in the Sun                                       12400000.0
# It's a Wonderful Life                                        NaN
# The Best Years of Our Lives                           21550000.0
# Gentleman's Agreement                                        NaN
# The Lady from Shanghai                                -2292073.0
# Tycoon                                                       NaN
# Open Secret                                                  NaN
# Red River                                                    NaN
# The Pirate                                             -744000.0
# Sands of Iwo Jima                                            NaN
# She Wore a Yellow Ribbon                                     NaN
# Annie Get Your Gun                                     4231215.0
# A Streetcar Named Desire                                     NaN
# Quo Vadis                                                    NaN
# Show Boat                                                    NaN
# Name: Net Earnings, dtype: float64

# %%
sorted_movies = movies[['Net Earnings']].sort_values(['Net Earnings'],ascending=[False]) 
print(sorted_movies.head(10))
# sorted_movies.head(10)['Net Earnings'].plot.barh()
# plt.show()
# Out:
#                                             Net Earnings
# Title
# Avatar                                       523505847.0
# Jurassic World                               502177271.0
# Titanic                                      458672302.0
# Star Wars: Episode IV - A New Hope           449935665.0
# E.T. the Extra-Terrestrial                   424449459.0
# The Avengers                                 403279547.0
# The Avengers                                 403279547.0
# The Lion King                                377783777.0
# Star Wars: Episode I - The Phantom Menace    359544677.0
# The Dark Knight                              348316061.0

# %% [markdown]
# #### Pivot Table in pandas

# %% [markdown]
# #### Advanced Excel users also often use pivot tables. A pivot table summarizes the data of another table by grouping the data on an index and applying operations such as sorting, summing, or averaging. You can use this feature in pandas too.
#
# #### We need to first identify the column or columns that will serve as the index, and the column(s) on which the summarizing formula will be applied. Let’s start small, by choosing Year as the index column and Gross Earnings as the summarization column and creating a separate DataFrame from this data.

# %%
movies_subset = movies[['Year', 'Gross Earnings']]
movies_subset.head()
# Out:
#                                                      Year  Gross Earnings
# Title
# Intolerance: Love's Struggle Throughout the Ages   1916.0             NaN
# Over the Hill to the Poorhouse                     1920.0       3000000.0
# The Big Parade                                     1925.0             NaN
# Metropolis                                         1927.0         26435.0
# Pandora's Box                                      1929.0          9950.0

# %%
earnings_by_year = movies_subset.pivot_table(index=['Year'])
earnings_by_year.head()
# Out:
#         Gross Earnings
# Year
# 1920.0       3000000.0
# 1927.0         26435.0
# 1929.0       1408975.0
# 1933.0       2300000.0
# 1935.0       3000000.0

# %%
earnings_by_year.plot()
plt.show()

# %%
movies_subset = movies[['Country', 'Language', 'Gross Earnings']]
movies_subset.head()
# Out:
#                                                    Country Language  \
# Title
# Intolerance: Love's Struggle Throughout the Ages       USA      NaN
# Over the Hill to the Poorhouse                         USA      NaN
# The Big Parade                                         USA      NaN
# Metropolis                                         Germany   German
# Pandora's Box                                      Germany   German
#
#                                                    Gross Earnings
# Title
# Intolerance: Love's Struggle Throughout the Ages              NaN
# Over the Hill to the Poorhouse                          3000000.0
# The Big Parade                                                NaN
# Metropolis                                                26435.0
# Pandora's Box                                              9950.0

# %%
earnings_by_co_lang = movies_subset.pivot_table(index=['Country', 'Language'])
earnings_by_co_lang.head()
# Out:
#                         Gross Earnings
# Country     Language
# Afghanistan Dari          1.127331e+06
# Argentina   Spanish       7.230936e+06
# Aruba       English       1.007614e+07
# Australia   Aboriginal    6.165429e+06
#             Dzongkha      5.052950e+05

# %%
earnings_by_co_lang.head(20).plot(kind='bar', figsize=(20,8))
plt.show()

# %% [markdown]
# #### Exporting the results to Excel

# %% [markdown]
# #### If you’re going to be working with colleagues who use Excel, saving Excel files out of pandas is important. You can export or write a pandas DataFrame to an Excel file using pandas to_excel method. Pandas uses the xlwt Python module internally for writing to Excel files.

# %%
movies.to_excel('result.xlsx', index=False)

# %% [markdown]
# #### Conclusion
# #### Pandas is not a replacement for Excel. Both tools have their place in the data analysis workflow and can be very great companion tools. As we demonstrated, pandas can do a lot of complex data analysis and manipulations, which depending on your need and expertise, can go beyond what you can achieve if you are just using Excel. One of the major benefits of using Python and pandas over Excel is that it helps you automate Excel file processing by writing scripts and integrating with your automated data workflow. Pandas also has excellent methods for reading all kinds of data from Excel files.
#
# ### Acquiring expertise in both pandas and Excel and making them work together gives you skills that can help you stand out in your organization.

# %% [markdown]
# ### CASE STUDY LINK -https://pbpython.com/excel-email.html

# %% [markdown]
# ### Documention-https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html
